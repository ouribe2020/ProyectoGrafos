# %%
from covid19dh import covid19
from datetime import date

# %%
x, src = covid19("BEL", cache = False, verbose = False,raw = False,start = date(2021,4,13),end = "2021-04-13")
x
# Out:
#        id       date   vaccines     tests  confirmed  recovered  deaths  \
# 6565  BEL 2021-04-13  2503818.0  11570070     927229      31130   23503
#
#         hosp  vent  icu  ...  currency  administrative_area_level  \
# 6565  2922.0     0  832  ...       EUR                          1
#
#       administrative_area_level_1  administrative_area_level_2  \
# 6565                      Belgium                          NaN
#
#       administrative_area_level_3  latitude  longitude  key  \
# 6565                          NaN   50.8333        4.0  NaN
#
#       key_apple_mobility  key_google_mobility
# 6565             Belgium                   BE
#
# [1 rows x 36 columns]

# %%
x, src = covid19("ESP", cache = False, verbose = False,raw = False,start = date(2021,4,13),end = "2021-04-13")
x
# Out:
#         id       date    vaccines     tests  confirmed  recovered  deaths  \
# 27201  ESP 2021-04-13  10784997.0  37012618    3370256     150376   76525
#
#          hosp  vent   icu  ...  currency  administrative_area_level  \
# 27201  7806.0     0  1855  ...       EUR                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 27201                        Spain                          NaN
#
#        administrative_area_level_3  latitude  longitude  key  \
# 27201                          NaN      40.0       -4.0  NaN
#
#        key_apple_mobility  key_google_mobility
# 27201               Spain                   ES
#
# [1 rows x 36 columns]
