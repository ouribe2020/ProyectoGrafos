# %%
from covid19dh import covid19
from datetime import date

# %%
x, src = covid19("CHL", cache = False, verbose = False,raw = False,start = date(2021,4,13),end = "2021-04-13")
x
# Out:
#         id       date    vaccines     tests  confirmed  recovered  deaths  \
# 16414  CHL 2021-04-13  12035524.0  11971224    1082920    1013416   24483
#
#          hosp  vent   icu  ...  currency  administrative_area_level  \
# 16414  8095.0     0  3203  ...       CLF                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 16414                        Chile                          NaN
#
#        administrative_area_level_3  latitude  longitude  key  \
# 16414                          NaN  -35.6751    -71.543  NaN
#
#        key_apple_mobility  key_google_mobility
# 16414               Chile                   CL
#
# [1 rows x 36 columns]

# %%
x, src = covid19("USA", cache = False, verbose = False,raw = False,start = date(2021,4,13),end = "2021-04-13")
x
# Out:
#         id       date     vaccines      tests  confirmed  recovered  deaths  \
# 87702  USA 2021-04-13  189692045.0  385064247   31268107    6298082  562533
#
#           hosp  vent   icu  ...  currency  administrative_area_level  \
# 87702  35536.0     0  8433  ...       USN                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 87702                United States                          NaN
#
#        administrative_area_level_3  latitude  longitude  key  \
# 87702                          NaN      38.0      -97.0  NaN
#
#        key_apple_mobility  key_google_mobility
# 87702       United States                   US
#
# [1 rows x 36 columns]
